# %%
import pandas as pd
import seaborn as sns

# %%
A = [25, -10, 10, 5, 35, 13]
B = [0, 15, -5, 5, 20, 25]
C = [10, 25, -15, -5, -5, 15]
yeld = pd.DataFrame({'A': A, 'B': B, 'C': C}, index = [1,2,3,4,5,6])
print(yeld)
# Out:
#     A   B   C
# 1  25   0  10
# 2 -10  15  25
# 3  10  -5 -15
# 4   5   5  -5
# 5  35  20  -5
# 6  13  25  15

# %%
sns.regplot(data=yeld, x='A', y='B', color='g')
plt.show()
sns.regplot(data=yeld, x='A', y='C', color='r')
plt.show()
sns.regplot(data=yeld, x='B', y='C', color='b')
plt.show()

# %% [markdown]
# #### З графіків вище слідує, що найменш залежні між собою акції А та В.
# Це можна підтвердити, порахувавши коефіцієнти кореляції:

# %%
print(yeld.corr())
# Out:
#           A         B         C
# A  1.000000  0.075439 -0.408807
# B  0.075439  1.000000  0.508034
# C -0.408807  0.508034  1.000000
